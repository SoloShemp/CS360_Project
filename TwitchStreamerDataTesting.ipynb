# %%
import pandas as pd
import time as time
import numpy as np
import matplotlib.pyplot as plt
import tkinter as tk
from tkinter import filedialog
from sklearn.preprocessing import MinMaxScaler


# You can borrow this for the rest of the semester to not have to worry about paths to your data
# you will see an example use case in problem 4
def open_file_dialog():
    root = tk.Tk()
    root.withdraw()
    return tk.filedialog.askopenfilename()

# %matplotlib inline

# %%
df = pd.read_csv(open_file_dialog())

# %%
df.head(5)
# Out:
#   platform channel_name channel_display_name  channel_id  hours_watched  \
# 0   twitch    riotgames           Riot Games    36029255       10347268
# 1   twitch   fextralife           Fextralife   156037856        4709216
# 2   twitch       gaules               Gaules   181077473        3891316
# 3   twitch    pgl_dota2            PGL_Dota2    87056709        3839088
# 4   twitch      otplol_              otplol_   622498423        2750139
#
#    peak_viewers  average_viewers  airtime_in_m  followers_gain  live_views  \
# 0        451088           140144          4430           63633  18089295.0
# 1         92467            46435          6085           48484   7947278.0
# 2        366056            23186         10070           16190   8666948.0
# 3        155951            65254          3530           34726  14999932.0
# 4        111180            16371         10080            5465   3935568.0
#
#                  last_streamed_game  \
# 0                 League of Legends
# 1                       Overwatch 2
# 2  Counter-Strike: Global Offensive
# 3                            Dota 2
# 4                 League of Legends
#
#                                           avatar_url channel_country  \
# 0  https://static-cdn.jtvnw.net/jtv_user_pictures...             NaN
# 1  https://static-cdn.jtvnw.net/jtv_user_pictures...             NaN
# 2  https://static-cdn.jtvnw.net/jtv_user_pictures...              BR
# 3  https://static-cdn.jtvnw.net/jtv_user_pictures...              RO
# 4  https://static-cdn.jtvnw.net/jtv_user_pictures...              FR
#
#   stream_language partnership_status  channel_type
# 0              en            partner  Organization
# 1              en            partner  Organization
# 2              pt            partner          Male
# 3              en            partner  Organization
# 4              fr            partner  Organization

# %%
df.shape
# Out:
# (100, 16)

# %%
df = df.drop(columns=["avatar_url", "channel_id", "platform", "channel_country","channel_display_name","channel_name"])

# %%
df
# Out:
#     hours_watched  peak_viewers  average_viewers  airtime_in_m  \
# 0        10347268        451088           140144          4430
# 1         4709216         92467            46435          6085
# 2         3891316        366056            23186         10070
# 3         3839088        155951            65254          3530
# 4         2750139        111180            16371         10080
# ..            ...           ...              ...           ...
# 95         391938         56095            18160          1295
# 96         385075         57689            19664          1175
# 97         382602         43140            27659           830
# 98         375314         14609             7094          3175
# 99         371915         19641            10284          2170
#
#     followers_gain  live_views                last_streamed_game  \
# 0            63633  18089295.0                 League of Legends
# 1            48484   7947278.0                       Overwatch 2
# 2            16190   8666948.0  Counter-Strike: Global Offensive
# 3            34726  14999932.0                            Dota 2
# 4             5465   3935568.0                 League of Legends
# ..             ...         ...                               ...
# 95            4059   1469738.0  Counter-Strike: Global Offensive
# 96           23912   3457789.0                            Dota 2
# 97           13025   1740764.0                         Minecraft
# 98            8404   1569656.0            Pokémon Community Game
# 99             498    848414.0                          Terraria
#
#    stream_language partnership_status  channel_type
# 0               en            partner  Organization
# 1               en            partner  Organization
# 2               pt            partner          Male
# 3               en            partner  Organization
# 4               fr            partner  Organization
# ..             ...                ...           ...
# 95              en            partner  Organization
# 96              en            partner           NaN
# 97              es            partner          Male
# 98              es            partner          Male
# 99              en            partner          Male
#
# [100 rows x 10 columns]

# %%
testing_df = df
testing_df
# Out:
#     hours_watched  peak_viewers  average_viewers  airtime_in_m  \
# 0        10347268        451088           140144          4430
# 1         4709216         92467            46435          6085
# 2         3891316        366056            23186         10070
# 3         3839088        155951            65254          3530
# 4         2750139        111180            16371         10080
# ..            ...           ...              ...           ...
# 95         391938         56095            18160          1295
# 96         385075         57689            19664          1175
# 97         382602         43140            27659           830
# 98         375314         14609             7094          3175
# 99         371915         19641            10284          2170
#
#     followers_gain  live_views                last_streamed_game  \
# 0            63633  18089295.0                 League of Legends
# 1            48484   7947278.0                       Overwatch 2
# 2            16190   8666948.0  Counter-Strike: Global Offensive
# 3            34726  14999932.0                            Dota 2
# 4             5465   3935568.0                 League of Legends
# ..             ...         ...                               ...
# 95            4059   1469738.0  Counter-Strike: Global Offensive
# 96           23912   3457789.0                            Dota 2
# 97           13025   1740764.0                         Minecraft
# 98            8404   1569656.0            Pokémon Community Game
# 99             498    848414.0                          Terraria
#
#    stream_language partnership_status  channel_type
# 0               en            partner  Organization
# 1               en            partner  Organization
# 2               pt            partner          Male
# 3               en            partner  Organization
# 4               fr            partner  Organization
# ..             ...                ...           ...
# 95              en            partner  Organization
# 96              en            partner           NaN
# 97              es            partner          Male
# 98              es            partner          Male
# 99              en            partner          Male
#
# [100 rows x 10 columns]

# %%
# Possible Naive Bayes Probabilities:
#-----------------------------------------------------------------------------------------
#
# Probability that new streamer whose average viewers is greater than 10,000 viewers
# but less than 80,000 viewers. What game did they last stream?
#
#-----------------------------------------------------------------------------------------
#
# Probability that new streamer whose stream language is french. Are they a partner or not?
#
#-----------------------------------------------------------------------------------------
#
# Proability that a new streamer whose airtime is 800<=airtime<=5000, plays Minecraft, and is a Male.
# What is there peak viewers?

# %%
testing_df
# Out:
#     hours_watched  peak_viewers  average_viewers  airtime_in_m  \
# 0        10347268        451088           140144          4430
# 1         4709216         92467            46435          6085
# 2         3891316        366056            23186         10070
# 3         3839088        155951            65254          3530
# 4         2750139        111180            16371         10080
# ..            ...           ...              ...           ...
# 95         391938         56095            18160          1295
# 96         385075         57689            19664          1175
# 97         382602         43140            27659           830
# 98         375314         14609             7094          3175
# 99         371915         19641            10284          2170
#
#     followers_gain  live_views                last_streamed_game  \
# 0            63633  18089295.0                 League of Legends
# 1            48484   7947278.0                       Overwatch 2
# 2            16190   8666948.0  Counter-Strike: Global Offensive
# 3            34726  14999932.0                            Dota 2
# 4             5465   3935568.0                 League of Legends
# ..             ...         ...                               ...
# 95            4059   1469738.0  Counter-Strike: Global Offensive
# 96           23912   3457789.0                            Dota 2
# 97           13025   1740764.0                         Minecraft
# 98            8404   1569656.0            Pokémon Community Game
# 99             498    848414.0                          Terraria
#
#    stream_language partnership_status  channel_type
# 0               en            partner  Organization
# 1               en            partner  Organization
# 2               pt            partner          Male
# 3               en            partner  Organization
# 4               fr            partner  Organization
# ..             ...                ...           ...
# 95              en            partner  Organization
# 96              en            partner           NaN
# 97              es            partner          Male
# 98              es            partner          Male
# 99              en            partner          Male
#
# [100 rows x 10 columns]

# %%
# Possible KNN Probabilities
#-----------------------------------------------------------------------------------------
# 
# A test point where:
# hours_watched=644329, peak_viewers=764932, avg_viewers=70337,

# %%
testing_df

# %%
# MinMax Scaling
#-----------------------------------------------------------------------------------------
# 
# MinMax scaling on Average Viewers, Hours Watched, Peak viewers, Airtime_in_m, Followers_gain, live_views

# %%
testing_df
scaler = MinMaxScaler()
print(scaler.fit(testing_df))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 testing_df
#       2 scaler = MinMaxScaler()
# ----> 3 print(scaler.fit(testing_df))
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:434, in MinMaxScaler.fit(self, X, y)
#     432 # Reset internal state before fitting
#     433 self._reset()
# --> 434 return self.partial_fit(X, y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:472, in MinMaxScaler.partial_fit(self, X, y)
#     466     raise TypeError(
#     467         "MinMaxScaler does not support sparse input. "
#     468         "Consider using MaxAbsScaler instead."
#     469     )
#     471 first_pass = not hasattr(self, "n_samples_seen_")
# --> 472 X = self._validate_data(
#     473     X,
#     474     reset=first_pass,
#     475     dtype=FLOAT_DTYPES,
#     476     force_all_finite="allow-nan",
#     477 )
#     479 data_min = np.nanmin(X, axis=0)
#     480 data_max = np.nanmax(X, axis=0)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:604, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     602         out = X, y
#     603 elif not no_val_X and no_val_y:
# --> 604     out = check_array(X, input_name="X", **check_params)
#     605 elif no_val_X and not no_val_y:
#     606     out = _check_y(y, **check_params)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:917, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         array = xp.astype(array, dtype, copy=False)
#     916     else:
# --> 917         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     918 except ComplexWarning as complex_warning:
#     919     raise ValueError(
#     920         "Complex data not supported\n{}\n".format(array)
#     921     ) from complex_warning
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:380, in _asarray_with_order(array, dtype, order, copy, xp)
#     378     array = numpy.array(array, order=order, dtype=dtype)
#     379 else:
# --> 380     array = numpy.asarray(array, order=order, dtype=dtype)
#     382 # At this point array is a NumPy ndarray. We convert it to an array
#     383 # container that is consistent with the input's namespace.
#     384 return xp.asarray(array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'League of Legends'

# %%
# Testing Twitch_data_42.csv
# Seems to be the same cols as 39,40,41
# Can drop cols: avatar_url, channel_id, platform
# Possibly can drop: channel_display_name, channel_name, 

# Testing channel.csv
# Can drop channel_id

# Testing time.csv
# Can drop channel_id

# Testing views.csv
# Can drop channel_id

# Testing Week Directory
# Unsure if anything should be dropped

# Testing Weekly Streamers ... .csv
# Unsure if anything should be dropped
